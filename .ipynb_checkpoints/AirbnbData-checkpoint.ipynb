# %% [markdown]
# ![Airbnb](imagem/Airbnb.png)
#
# #### Dicionário de dados em inglês
# About Dataset
#
# This extensive dataset offers a detailed glimpse into the dynamic world of Airbnb accommodations spanning diverse locations worldwide. From cozy apartments in bustling urban centers to serene retreats nestled in picturesque countryside, this collection provides valuable insights into the various types of lodging options available on the Airbnb platform. With comprehensive information on property features, pricing, reviews, and host characteristics, researchers and enthusiasts alike can delve into the intricate ecosystem of shared lodging, uncovering trends, patterns, and preferences that shape the evolving landscape of modern hospitality. Whether analyzing market trends, assessing the impact of tourism on local economies, or simply satisfying a curiosity about global travel trends, this dataset serves as a rich resource for exploring the multifaceted realm of Airbnb accommodations. <BR>
#
#
# - id
# - log_price
# - property_type
# - room_type
# - amenities
# - accommodates
# - bathrooms
# - bed_type
# - cancellation_policy
# - cleaning_fee, city
# - description
# - first_review
# - host_has_profile_pic
# - host_identity_verified
# - host_response_rate
# - host_since
# - instant_bookable
# - last_review
# - latitude
# - longitude
# - name
# - neighbourhood
# - number_of_reviews
# - review_scores_rating
# - thumbnail_url
# - zipcode
# - bedrooms
# - beds
#
#
# #### Dicionário de dados em português
#
# Sobre o Conjunto de Dados
#
# Este extenso conjunto de dados oferece um vislumbre detalhado do mundo dinâmico das acomodações do Airbnb, abrangendo diversas localidades ao redor do mundo. Desde apartamentos aconchegantes em centros urbanos movimentados até retiros serenos escondidos na paisagem pitoresca do campo, esta coleção fornece insights valiosos sobre os diversos tipos de opções de hospedagem disponíveis na plataforma do Airbnb. Com informações abrangentes sobre características da propriedade, preços, avaliações e características dos anfitriões, pesquisadores e entusiastas podem mergulhar no ecossistema intricado da hospedagem compartilhada, descobrindo tendências, padrões e preferências que moldam o cenário em constante evolução da hospitalidade moderna. Seja analisando as tendências de mercado, avaliando o impacto do turismo nas economias locais, ou simplesmente satisfazendo a curiosidade sobre as tendências de viagem globais, este conjunto de dados serve como um recurso rico para explorar o reino multifacetado das acomodações do Airbnb.
#
# - id: Identificação única para cada entrada de dados. <BR>
# - preço do registro: Preço da hospedagem por noite. <BR>
# - Tipo de Propriedade: Categoria da propriedade (apartamento, casa, quarto compartilhado, etc.).<BR>
# - tipo de sala: Tipo de espaço (quarto privado, espaço compartilhado, casa inteira, etc.).<BR>
# - Facilidades: Amenidades oferecidas na propriedade.<BR>
# - acomoda(cabe x pessoas): Capacidade máxima de hóspedes.<BR>
# - banheiros: Número de banheiros na propriedade.<BR>
# - tipo de cama: Tipo de cama disponível (cama de casal, sofá-cama, beliche, etc.).<BR>
# - política de cancelamento: Tipo de política de cancelamento aplicada.<BR>
# - taxa de limpeza: Taxa adicional de limpeza cobrada.<BR>
# - cidade: Cidade onde está localizada a propriedade.<BR>
# - descrição: Descrição da propriedade.<BR>
# - primeira revisão: Data da primeira revisão.<BR>
# - anfitrião tem foto de perfil: Indica se o anfitrião possui foto de perfil.<BR>
# - identidade do host verificada: Indica se a identidade do anfitrião foi verificada.<BR>
# - taxa de resposta do host: Taxa de resposta do anfitrião a consultas de potenciais hóspedes.<BR>
# - anfitrião desde: Data de entrada do anfitrião na plataforma.<BR>
# - reserva instantânea: Indica se a reserva é instantânea.<BR>
# - última revisão: Data da última revisão.<BR>
# - latitude: Coordenada geográfica da latitude.<BR>
# - longitude: Coordenada geográfica da longitude.<BR>
# - nome: Nome da propriedade.<BR>
# - vizinhança: Bairro ou área onde está localizada a propriedade.<BR>
# - número de comentários: Número total de comentários recebidos.<BR>
# - avaliação de pontuações de revisão: Avaliação média baseada nas revisões dos hóspedes.<BR>
# - URL da miniatura: URL para uma imagem em miniatura da propriedade.<BR>
# - CEP: Código postal da localização.<BR>
# - quartos de dormir: Número de quartos disponíveis.<BR>
# - camas: Número total de camas na propriedade.<BR>
#
#
# URL DataSet: https://www.kaggle.com/datasets/lovishbansal123/airbnb-data

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.9.13

# %%
# Instala o pacote watermark. 
# Esse pacote é usado para gravar as versões de outros pacotes usados neste jupyter notebook.
# !pip install -q -U watermark

# %%
#pacote para criar mapa de valores de ausentes(fundamental em analise de dados)
# !pip install -q missingno

# %%
#pacote para criação de grafico em alto nivel em linguaguem python
# !pip install -q plotly

# %%
# Imports

# Manipulação de dados
import pandas as pd
import numpy as np

# Visualização
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import missingno
import sys, os

# Estatística
import scipy
from scipy.stats import normaltest
from scipy.stats import chi2_contingency

# Engenharia de Atributos
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

# Ignore Warning
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
# Vamos adicionar caminho para os módulos Python
sys.path.append(os.path.abspath(os.path.join('modulos')))
from estrategia1 import *
from estrategia2 import *
from estrategia3 import *

# %%
# Ignora
# Versões dos pacotes usados neste jupyter notebook
# %reload_ext watermark
# %watermark -a "Data Science Academy" --iversions
# Out:
# Author: Data Science Academy
#
# pandas    : 1.5.3
# seaborn   : 0.11.2
# sys       : 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# plotly    : 5.9.0
# matplotlib: 3.5.2
# missingno : 0.5.2
# numpy     : 1.21.5
# scipy     : 1.9.1

# %% [markdown]
# # Carrega o dataset

# %%
# Carrega o dataset
df = pd.read_csv("Airbnb_Data.csv")

# %%
# Amostra dos dados
df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...   latitude   longitude  \
# 0  Real Bed              strict          True  ...  40.696524  -73.991617
# ...

# %%
# Shape
df.shape
# Out:
# (74111, 29)

# %%
# Colunas
df.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %% [markdown]
# ## Análise Exploratória de Dados

# %%
# Informações gerais dos dados
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
# ...

# %%
# Estatísticas descritivas
df.describe(include = object)
# Out:
#        property_type        room_type amenities  bed_type cancellation_policy  \
# count          74111            74111     74111     74111               74111
# unique            35                3     67122         5                   5
# top        Apartment  Entire home/apt        {}  Real Bed              strict
# freq           49003            41310       586     72028               32374
#
#          city                                        description first_review  \
# count   74111                                              74111        58247
# unique      6                                              73479         2554
# top       NYC  Hello, I've been running guest house for Korea...   2017-01-01
# freq    32349                                                  8          293
#
#        host_has_profile_pic host_identity_verified host_response_rate  \
# count                 73923                  73923              55812
# ...

# %%
# Estatísticas descritivas
df.describe().drop(columns = ['id', 'latitude', 'longitude'])
# Out:
#           log_price  accommodates     bathrooms  number_of_reviews  \
# count  74111.000000  74111.000000  73911.000000       74111.000000
# mean       4.782069      3.155146      1.235263          20.900568
# std        0.717394      2.153589      0.582044          37.828641
# min        0.000000      1.000000      0.000000           0.000000
# 25%        4.317488      2.000000      1.000000           1.000000
# 50%        4.709530      2.000000      1.000000           6.000000
# 75%        5.220356      4.000000      1.000000          23.000000
# max        7.600402     16.000000      8.000000         605.000000
#
#        review_scores_rating      bedrooms          beds
# count          57389.000000  74020.000000  73980.000000
# mean              94.067365      1.265793      1.710868
# std                7.836556      0.852143      1.254142
# min               20.000000      0.000000      0.000000
# 25%               92.000000      1.000000      1.000000
# ...

# %%
average_review_scores1 = df.groupby('property_type')[['host_has_profile_pic','host_identity_verified']].value_counts()

# %%
print(average_review_scores1 )
# Out:
# property_type    host_has_profile_pic  host_identity_verified
# Apartment        t                     t                         32678
#                                        f                         16004
#                  f                     f                           151
#                                        t                             7
# Bed & Breakfast  t                     t                           259
#                                                                  ...
# Villa            t                     t                           123
#                                        f                            55
#                  f                     f                             1
# Yurt             t                     t                             7
#                                        f                             2
# Length: 74, dtype: int64

# %%
# Figura
plt.figure(figsize = (17,12))

# Subplots com histogramas
#posição é o numero
plt.subplot(221)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['log_price'], kde = True, color = "green")
plt.title('Histograma do log_price', fontsize = 20)

# Subplots com histogramas
#posição é o numero
plt.subplot(222)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['accommodates'], kde = True, color = "green")
plt.title('Histograma do accommodates', fontsize = 20)

# Subplots com histogramas
#posição é o numero
plt.subplot(223)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['bathrooms'], kde = True, color = "green")
plt.title('Histograma do bathrooms', fontsize = 20)

# Subplots com histogramas
#posição é o numero
plt.subplot(224)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['number_of_reviews'], kde = True, color = "green")
plt.title('Histograma do number_of_reviews', fontsize = 20)


plt.show()

# %%
# Figura
plt.figure(figsize = (17,12))

# Subplots com histogramas
#posição é o numero
plt.subplot(221)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['review_scores_rating'], kde = True, color = "green")
plt.title('Histograma do review_scores_rating', fontsize = 20)

# Subplots com histogramas
#posição é o numero
plt.subplot(222)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['bedrooms'], kde = True, color = "green")
plt.title('Histograma do bedrooms', fontsize = 20)

# Subplots com histogramas
#posição é o numero
plt.subplot(223)
#palieta de cor
sns.color_palette("hls", 8)
sns.histplot(df['beds'], kde = True, color = "green")
plt.title('Histograma do beds', fontsize = 20)


plt.show()

# %% [markdown]
# **log_price:** Indicando uma distribuição equilibrada dos dados. O desvio padrão de 0.717394 mostra que os preços variam em torno da média, mas não de forma excessivamente dispersa. Em resumo, os preços parecem estar relativamente estáveis, sem muita variação extrema em relação à média.
#
# **accommodates:** Revelam que a distribuição é enviesada para a direita, com a maioria das acomodações agrupadas em números menores, mas com alguns valores extremamente altos que elevam a média. O desvio padrão mostra que os dados estão dispersos em relação à média, indicando uma variabilidade considerável. Em suma, enquanto a maioria das observações tem um número menor de acomodações, há casos onde o número é substancialmente maior, o que contribui para a média ser mais alta que a mediana.
#
# **bathrooms:** Essas estatísticas revelam que o número de banheiros varia entre as observações, mas com uma tendência central em torno de 1. Em média, as propriedades têm um pouco mais de um banheiro, enquanto a mediana de 1 sugere que metade das propriedades tem exatamente um banheiro. Em resumo, a maioria das propriedades parece ter um banheiro, com algumas tendo mais do que a média.
#
# **number_of_reviews:** O número de avaliações por propriedade varia consideravelmente. A média de 20.900568 indica que, em média, as propriedades têm cerca de 20 avaliações, mas a mediana de 6.000000 mostra que metade das propriedades tem seis ou menos avaliações. O desvio padrão de 37.828641 é relativamente alto, indicando uma dispersão considerável em torno da média. Isso sugere que algumas propriedades podem ter um número muito maior de avaliações, contribuindo para uma média mais alta. Em resumo, enquanto a maioria das propriedades tem um número modesto de avaliações, há algumas com um número significativamente maior, aumentando a média.
#
# **review_scores_rating:** A maioria das propriedades tem pontuações de avaliação próximas à média, com poucas pontuações extremamente altas ou baixas que afetam significativamente a média. Em resumo, as propriedades geralmente têm pontuações de avaliação elevadas, com uma dispersão moderada em torno da média.
#
# **bedrooms:** Isso sugere que algumas propriedades podem ter um número muito maior de quartos, contribuindo para uma média mais alta. Em resumo, enquanto a maioria das propriedades tem um número modesto de quartos, há algumas com um número significativamente maior, aumentando a média.
#
# **beds:** Isso sugere que algumas propriedades podem ter um número muito maior de camas, contribuindo para uma média mais alta. Em resumo, enquanto a maioria das propriedades tem um número modesto de camas, há algumas com um número significativamente maior, aumentando a média

# %% [markdown]
# ![Airbnb](imagem/Airbnb.png)
#
# #### Remoção de colunas
# Para otimizar a análise de dados e focar nas questões de negócios relevantes, é crucial remover colunas do conjunto de dados que não contribuem diretamente para responder às perguntas comerciais específicas. Essas colunas adicionais podem incluir informações irrelevantes, redundantes ou irrelevantes para os objetivos da análise. Ao remover essas colunas, estamos simplificando o conjunto de dados, tornando-o mais fácil de entender e analisar, além de reduzir a sobrecarga computacional.

# %%
#copiando o dataset
new_df = df.copy()

# %%
#deletando algumas colunas
new_df.drop(['first_review', 'host_has_profile_pic','host_identity_verified', 'host_since',
                  'last_review', 'latitude','longitude'], axis=1, inplace=True)

# %%
# Amostra dos dados
new_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ... host_response_rate  \
# 0  Real Bed              strict          True  ...                NaN
# ...

# %% [markdown]
# ### Identificando e correção de Valores Ausentes

# %%
# Valores ausentes por coluna
null_df = new_df.isna().sum().reset_index()

# Figura
ax = plt.figure(figsize = (15,5))

# Barplot
#primeira coluna, null_df['index'], contém os nomes das colunas do DataFrame original que possuem valores ausentes, 
#enquanto a segunda coluna, null_df[0], contém as contagens de valores ausentes associadas a cada uma das colunas.
ax = sns.barplot(null_df['index'], null_df[0], palette = 'husl')
plt.xlabel('Atributos', fontsize = 12)
plt.ylabel('Contagem de Valores Ausentes', fontsize = 12)
plt.xticks(rotation = 45)
plt.title("Plot de Valores Ausentes", fontsize = 15)

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, (p.get_height())), ha = 'center', color = 'black', size = 11)

plt.show()

# %%
# new_df onde o valor da coluna 'log_price' é igual a 0 ou menor ou igual a 1.9.
nan_index = (new_df[(new_df['log_price'] == 0) | (new_df['log_price'] <= 1.9)]).index

# %%
#quantidade
len(nan_index)
# Out:
# 2

# %%
#substitua pela mediana do log_price
new_df['log_price'][nan_index] = 4.709530

# %%
#verificando se tem menor que o valor
valor = 2.0
resultados = new_df[new_df['log_price'] < valor]

# Exiba os resultados
print(resultados)
# Out:
# Empty DataFrame
# Columns: [id, log_price, property_type, room_type, amenities, accommodates, bathrooms, bed_type, cancellation_policy, cleaning_fee, city, description, host_response_rate, instant_bookable, name, neighbourhood, number_of_reviews, review_scores_rating, thumbnail_url, zipcode, bedrooms, beds]
# Index: []
#
# [0 rows x 22 columns]

# %%
# Plot
# O código gera um gráfico de contagem para a variável 'bathrooms' com valores ausentes preenchidos,
# destacando as alturas das barras.
sns.countplot(data = new_df.fillna('NaN'), x = 'bathrooms', alpha = 0.7, edgecolor = 'black')
sns.despine()
plt.xticks()
bound=ax.get_xbound()
ax=plt.gca()
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()), ha = 'center', color = 'black', size = 10)
plt.title("Valores Ausentes da Variável bathrooms Antes do Processamento\n", fontsize = 15)
plt.show()

# %%
# inserindo valor ao valores NaN
new_df['bathrooms'].fillna(1, inplace=True)

# %%
# Transformando a coluna no tipo int
new_df['bathrooms'] = new_df['bathrooms'].astype(int)

# %%
# Plot
# O código gera um gráfico de contagem para a variável 'bathrooms' com valores ausentes preenchidos,
# destacando as alturas das barras.
sns.countplot(data = new_df.fillna('NaN'), x = 'bathrooms', alpha = 0.7, edgecolor = 'black')
sns.despine()
plt.xticks()
bound=ax.get_xbound()
ax=plt.gca()
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()), ha = 'center', color = 'black', size = 10)
plt.title("Valores Ausentes da Variável bathrooms Antes do Processamento\n", fontsize = 15)
plt.show()

# %%
# Valores únicos
new_df['host_response_rate'].unique()
# Out:
# array([nan, '100%', '71%', '68%', '67%', '83%', '50%', '90%', '86%',
#        '92%', '82%', '80%', '89%', '93%', '99%', '0%', '88%', '96%',
#        '70%', '94%', '91%', '25%', '95%', '98%', '62%', '29%', '33%',
#        '81%', '63%', '38%', '60%', '79%', '78%', '75%', '65%', '97%',
#        '87%', '40%', '54%', '53%', '58%', '76%', '30%', '64%', '17%',
#        '20%', '77%', '73%', '41%', '59%', '57%', '85%', '56%', '42%',
#        '44%', '35%', '14%', '74%', '27%', '10%', '84%', '6%', '72%',
#        '36%', '55%', '43%', '13%', '39%', '46%', '26%', '61%', '52%',
#        '23%', '22%', '69%', '66%', '15%', '11%', '31%', '21%', '47%'],
#       dtype=object)

# %%
new_df['host_response_rate'] = np.where(
    new_df['host_response_rate'].notna(),  # condição: verifica se o valor não é NaN
    new_df['host_response_rate'].str.replace('%', ''),  # valor se a condição for True
    new_df['host_response_rate']  # valor se a condição for False (ou seja, se for NaN)
)

# %%
# Preenche os valores NaN com 100 ou qualquer outro valor padrão desejado
new_df['host_response_rate'].fillna(100, inplace=True)

# %%
# Transformando a coluna no tipo int
new_df['host_response_rate'] = new_df['host_response_rate'].astype(int)

# %%
# Info
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    74111 non-null  int64
#  1   log_price             74111 non-null  float64
#  2   property_type         74111 non-null  object
#  3   room_type             74111 non-null  object
#  4   amenities             74111 non-null  object
#  5   accommodates          74111 non-null  int64
#  6   bathrooms             74111 non-null  int32
#  7   bed_type              74111 non-null  object
#  8   cancellation_policy   74111 non-null  object
#  9   cleaning_fee          74111 non-null  bool
#  10  city                  74111 non-null  object
#  11  description           74111 non-null  object
#  12  host_response_rate    74111 non-null  int32
#  13  instant_bookable      74111 non-null  object
#  14  name                  74111 non-null  object
# ...

# %%
# Amostra dos dados
new_df.head()
# Out:
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3          1
# 1  {"Wireless Internet","Air conditioning",Kitche...             7          1
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5          1
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4          1
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2          1
#
#    bed_type cancellation_policy  cleaning_fee  ... host_response_rate  \
# 0  Real Bed              strict          True  ...                100
# ...

# %%
# Valores únicos
new_df['neighbourhood'].unique()
# Out:
# array(['Brooklyn Heights', "Hell's Kitchen", 'Harlem', 'Lower Haight',
#        'Columbia Heights', 'Noe Valley', nan, 'Downtown',
#        'Richmond District', 'Alphabet City', 'Hermosa Beach', 'Torrance',
#        'U Street Corridor', 'Humboldt Park', 'Wicker Park',
#        'South Boston', 'Lower East Side', 'Flatbush', 'Sherman Oaks',
#        'East Flatbush', 'Valley Glen', 'Dupont Circle', 'Jamaica',
#        'Forest Hills', 'Murray Hill', 'Lefferts Garden', 'Mid-Wilshire',
#        'Venice', 'West Hollywood', 'Brownsville', 'Williamsburg',
#        'East Village', 'South Loop/Printers Row', 'Westlake',
#        'Hollywood Hills', 'Upper East Side', 'Bushwick',
#        'Bedford-Stuyvesant', 'Pilsen', 'Chelsea', 'Sunnyside',
#        'Greenwich Village', 'Washington Heights', 'Pasadena',
#        'Potrero Hill', 'Brookland', 'Los Feliz', 'Hollywood',
#        'Midtown East', 'Glendale', 'Park Slope', 'Arcadia',
# ...

# %%
# Preenche os valores NaN com Unknown ou qualquer outro valor padrão desejado
new_df['neighbourhood'].fillna('Unknown', inplace=True)

# %%
# Valores ausentes por coluna
null_df = new_df.isna().sum().reset_index()

# Figura
ax = plt.figure(figsize = (15,5))

# Barplot
#primeira coluna, null_df['index'], contém os nomes das colunas do DataFrame original que possuem valores ausentes, 
#enquanto a segunda coluna, null_df[0], contém as contagens de valores ausentes associadas a cada uma das colunas.
ax = sns.barplot(null_df['index'], null_df[0], palette = 'husl')
plt.xlabel('Atributos', fontsize = 12)
plt.ylabel('Contagem de Valores Ausentes', fontsize = 12)
plt.xticks(rotation = 45)
plt.title("Plot de Valores Ausentes", fontsize = 15)

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, (p.get_height())), ha = 'center', color = 'black', size = 11)

plt.show()

# %%
# Valores únicos

new_df['review_scores_rating'].unique()
# Out:
# array([100.,  93.,  92.,  nan,  40.,  97.,  99.,  90.,  89.,  91.,  88.,
#         86.,  72.,  98.,  95.,  96.,  84.,  80.,  94.,  87.,  85.,  70.,
#         60.,  75.,  20.,  76.,  83.,  82.,  78.,  73.,  55.,  81.,  67.,
#         71.,  77.,  79.,  47.,  74.,  68.,  66.,  63.,  50.,  53.,  65.,
#         64.,  27.,  69.,  30.,  58.,  35.,  62.,  49.,  57.,  54.,  56.])

# %%
#contagem para cada valor em review_scores_rating
contagem_valores = new_df['review_scores_rating'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# 100.0    16215
# 98.0      4374
# 97.0      4087
# 96.0      4081
# 95.0      3713
# 93.0      3647
# 90.0      2852
# 99.0      2631
# 94.0      2618
# 80.0      2163
# 92.0      2064
# 91.0      1615
# 89.0      1120
# 87.0      1119
# 88.0      1056
# 85.0       625
# 86.0       512
# 60.0       444
# 84.0       438
# 83.0       403
# 82.0       211
# 70.0       196
# 73.0       157
# 81.0       126
# 75.0       101
# 20.0        97
# 78.0        94
# 40.0        90
# 79.0        83
# 76.0        76
# 77.0        74
# 67.0        66
# 74.0        39
# 72.0        38
# 50.0        30
# 65.0        28
# 68.0        20
# 71.0        14
# 69.0        13
# 63.0        11
# 53.0        10
# 64.0        10
# 47.0         5
# 30.0         4
# 62.0         3
# 66.0         3
# 55.0         3
# 57.0         3
# 27.0         2
# 35.0         1
# 49.0         1
# 58.0         1
# 54.0         1
# 56.0         1
# Name: review_scores_rating, dtype: int64

# %%
# Preenche os valores NaN com 100 ou qualquer outro valor padrão desejado
new_df['review_scores_rating'].fillna(100, inplace=True)

# %%
# valor da coluna 'review_scores_rating' é "Unknown". Os índices encontrados são armazenados na variável Unknown_nan
Unknown_nan = (new_df[(new_df['review_scores_rating'] == "Unknown")]).index

# %%
# Quantidade recebida em Unknow_nan
len(Unknown_nan)
# Out:
# 0

# %%
# Valore serão substituido por 100
new_df['review_scores_rating'][Unknown_nan] = 100

# %%
# Valores ausentes por coluna
null_df = new_df.isna().sum().reset_index()

# Figura
ax = plt.figure(figsize = (15,5))

# Barplot
#primeira coluna, null_df['index'], contém os nomes das colunas do DataFrame original que possuem valores ausentes, 
#enquanto a segunda coluna, null_df[0], contém as contagens de valores ausentes associadas a cada uma das colunas.
ax = sns.barplot(null_df['index'], null_df[0], palette = 'husl')
plt.xlabel('Atributos', fontsize = 12)
plt.ylabel('Contagem de Valores Ausentes', fontsize = 12)
plt.xticks(rotation = 45)
plt.title("Plot de Valores Ausentes", fontsize = 15)

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, (p.get_height())), ha = 'center', color = 'black', size = 11)

plt.show()

# %%
contagem_valores = new_df['thumbnail_url'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# https://a0.muscache.com/im/pictures/70087089/bc66229a_original.jpg?aki_policy=small              3
# https://a0.muscache.com/im/pictures/23033013/54d62516_original.jpg?aki_policy=small              2
# https://a0.muscache.com/im/pictures/104667326/a7a2b145_original.jpg?aki_policy=small             2
# https://a0.muscache.com/im/pictures/95059281/d8bfc436_original.jpg?aki_policy=small              2
# https://a0.muscache.com/im/pictures/4491e5c5-33f6-4704-9887-76a059f86fda.jpg?aki_policy=small    2
#                                                                                                 ..
# https://a0.muscache.com/im/pictures/111150220/7099e1de_original.jpg?aki_policy=small             1
# https://a0.muscache.com/im/pictures/bfc6695c-93f9-4a90-a6d8-9f6c038fff28.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/99319739/70c4beaf_original.jpg?aki_policy=small              1
# ...

# %%
# Preenche os valores NaN com Unknown ou qualquer outro valor padrão desejado
new_df['thumbnail_url'].fillna('Unknown', inplace=True)

# %%
contagem_valores = new_df['thumbnail_url'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# Unknown                                                                                          8216
# https://a0.muscache.com/im/pictures/70087089/bc66229a_original.jpg?aki_policy=small                 3
# https://a0.muscache.com/im/pictures/39dc7b1a-15ca-4820-ac7d-44325007f1a2.jpg?aki_policy=small       2
# https://a0.muscache.com/im/pictures/105275678/2ec252ae_original.jpg?aki_policy=small                2
# https://a0.muscache.com/im/pictures/61042471/5543b0e0_original.jpg?aki_policy=small                 2
#                                                                                                  ...
# https://a0.muscache.com/im/pictures/111150220/7099e1de_original.jpg?aki_policy=small                1
# https://a0.muscache.com/im/pictures/bfc6695c-93f9-4a90-a6d8-9f6c038fff28.jpg?aki_policy=small       1
# https://a0.muscache.com/im/pictures/99319739/70c4beaf_original.jpg?aki_policy=small                 1
# ...

# %%
# contando valores da zipcode
contagem_valores = new_df['zipcode'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# 11211.0       1368
# 90291         1274
# 11221         1188
# 94110          988
# 90046          967
#               ...
# 10025.0          1
# 91606-1412       1
# 20781            1
# 15074            1
# 10012.0          1
# Name: zipcode, Length: 769, dtype: int64

# %%
# Preenche os valores NaN com Unknown ou qualquer outro valor padrão desejado

new_df['zipcode'].fillna('Unknown', inplace=True)

# %%
# contando valores da bedrooms
contagem_valores = new_df['bedrooms'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# 1.0     49784
# 2.0     11351
# 0.0      6715
# 3.0      4309
# 4.0      1330
# 5.0       355
# 6.0       106
# 7.0        38
# 8.0        14
# 10.0       10
# 9.0         8
# Name: bedrooms, dtype: int64

# %%
# Preenche os valores NaN com 1 ou qualquer outro valor padrão desejado
new_df['bedrooms'].fillna(1, inplace=True)

# %%
new_df['bedrooms'] = new_df['bedrooms'].astype(int)

# %%
# contando valores da beds
contagem_valores = new_df['beds'].value_counts()

# Exibir a contagem de valores
print(contagem_valores)
# Out:
# 1.0     45144
# 2.0     16704
# 3.0      6442
# 4.0      3065
# 5.0      1287
# 6.0       661
# 7.0       216
# 8.0       186
# 10.0       88
# 9.0        72
# 16.0       38
# 12.0       29
# 11.0       23
# 13.0       10
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: beds, dtype: int64

# %%
# Preenche os valores NaN com 1 ou qualquer outro valor padrão desejado
new_df['beds'].fillna(1, inplace=True)

# %%
# Valores ausentes por coluna
null_df = new_df.isna().sum().reset_index()

# Figura
ax = plt.figure(figsize = (15,5))

# Barplot
#primeira coluna, null_df['index'], contém os nomes das colunas do DataFrame original que possuem valores ausentes, 
#enquanto a segunda coluna, null_df[0], contém as contagens de valores ausentes associadas a cada uma das colunas.
ax = sns.barplot(null_df['index'], null_df[0], palette = 'husl')
plt.xlabel('Atributos', fontsize = 12)
plt.ylabel('Contagem de Valores Ausentes', fontsize = 12)
plt.xticks(rotation = 45)
plt.title("Plot de Valores Ausentes", fontsize = 15)

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, (p.get_height())), ha = 'center', color = 'black', size = 11)

plt.show()

# %%
# Verificando se possui valores ausentes
new_df.isnull().sum()
# Out:
# id                      0
# log_price               0
# property_type           0
# room_type               0
# amenities               0
# accommodates            0
# bathrooms               0
# bed_type                0
# cancellation_policy     0
# cleaning_fee            0
# city                    0
# description             0
# host_response_rate      0
# instant_bookable        0
# name                    0
# neighbourhood           0
# number_of_reviews       0
# review_scores_rating    0
# thumbnail_url           0
# zipcode                 0
# bedrooms                0
# beds                    0
# dtype: int64

# %%
# Transformando colunas para float
new_df['accommodates'] = new_df['accommodates'].astype(float)
new_df['number_of_reviews'] = new_df['number_of_reviews'].astype(float)

# %%
# Info
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    74111 non-null  int64
#  1   log_price             74111 non-null  float64
#  2   property_type         74111 non-null  object
#  3   room_type             74111 non-null  object
#  4   amenities             74111 non-null  object
#  5   accommodates          74111 non-null  float64
#  6   bathrooms             74111 non-null  int32
#  7   bed_type              74111 non-null  object
#  8   cancellation_policy   74111 non-null  object
#  9   cleaning_fee          74111 non-null  bool
#  10  city                  74111 non-null  object
#  11  description           74111 non-null  object
#  12  host_response_rate    74111 non-null  int32
#  13  instant_bookable      74111 non-null  object
#  14  name                  74111 non-null  object
# ...

# %% [markdown]
# ### Identificação e remoção de Valores Duplicados

# %%
# Valores duplicados
df['id'].duplicated().sum()
# Out:
# 0

# %%
# Valores duplicados
new_df['id'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Tratamento de Outliers

# %%
# Copia dataframe
df_final = new_df.copy()

# %%
# Cria o objeto trata outlier
#outlier são para valores numericos
trata_outlier = TrataOutlier(df_final)

# %%
# Lista de colunas float64
lista_colunas = df_final.select_dtypes('float64').columns.tolist()

# %%
lista_colunas
# Out:
# ['log_price',
#  'accommodates',
#  'number_of_reviews',
#  'review_scores_rating',
#  'beds']

# %%
# Visão geral dos outliers
trata_outlier.getOverview(lista_colunas)
# Out:
# Nome de Coluna   number_of_reviews      beds review_scores_rating  \
# Min                            0.0       0.0                 20.0
# Q1                             1.0       1.0                 93.0
# Median                         6.0       1.0                 98.0
# Q3                            23.0       2.0                100.0
# Max                          605.0      18.0                100.0
# IQR                           22.0       1.0                  7.0
# Lower fence                  -32.0      -0.5                 82.5
# Upper fence                   56.0       3.5                110.5
# Skew                      3.702835  3.360796            -3.635688
# Num_Outliers                  8203      5686                 4219
# Percent_Outliers             5.47%     3.79%                2.81%
#
# Nome de Coluna   accommodates log_price
# Min                       1.0  2.302585
# Q1                        2.0  4.317488
# Median                    2.0   4.70953
# ...

# %%
# Replace dos outliers
trata_outlier.replace_outliers_with_fences(lista_colunas)

# %%
# Visão geral dos outliers
trata_outlier.getOverview(lista_colunas)
# Out:
# Nome de Coluna   log_price accommodates number_of_reviews  \
# Min               2.963187          1.0               0.0
# Q1                4.317488          2.0               1.0
# Median             4.70953          2.0               6.0
# Q3                5.220356          4.0              23.0
# Max               6.574657          7.0              56.0
# IQR               0.902868          2.0              22.0
# Lower fence       2.963187         -1.0             -32.0
# Upper fence       6.574657          7.0              56.0
# Skew              0.362717     0.958996          1.200091
# Num_Outliers             0            0                 0
# Percent_Outliers      0.0%         0.0%              0.0%
#
# Nome de Coluna   review_scores_rating      beds
# Min                              82.5       0.0
# Q1                               93.0       1.0
# Median                           98.0       1.0
# Q3                              100.0       2.0
# ...

# %%
# Descritiva
df_final.describe()
# Out:
#                  id     log_price  accommodates     bathrooms  \
# count  7.411100e+04  74111.000000  74111.000000  74111.000000
# mean   1.126662e+07      4.776129      3.018067      1.192940
# std    6.081735e+06      0.696019      1.695036      0.544971
# min    3.440000e+02      2.963187      1.000000      0.000000
# 25%    6.261964e+06      4.317488      2.000000      1.000000
# 50%    1.225415e+07      4.709530      2.000000      1.000000
# 75%    1.640226e+07      5.220356      4.000000      1.000000
# max    2.123090e+07      6.574657      7.000000      8.000000
#
#        host_response_rate  number_of_reviews  review_scores_rating  \
# count        74111.000000       74111.000000          74111.000000
# mean            95.746542          15.182294             95.910101
# std             14.389110          19.130995              5.239834
# min              0.000000           0.000000             82.500000
# 25%            100.000000           1.000000             93.000000
# ...

# %% [markdown]
# ![Airbnb](imagem/Airbnb.png)
#
# #### Perguntas abaixo que deverão ser respondidas
# - Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?
# - Qual é a média de preços de hospedagem em diferentes tipos de propriedades (apartamentos, casas, quartos compartilhados, etc.) e em diferentes cidades?
# - Existe alguma correlação entre o número de comodidades oferecidas e o preço da hospedagem?
# - Qual é a média de avaliação dos hóspedes em relação à taxa de limpeza cobrada?
# - Quais são as áreas mais populares (baseadas no número de reservas) em cada cidade?
# - Quais são os bairros mais caros e mais baratos para se hospedar em cada cidade?

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?


# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['property_type'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Tipo de Propriedade', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?

# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['room_type'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Tipo de Quarto', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?

# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['bathrooms'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Quantidade de banheiros', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?

# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['bed_type'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Tipo de Cama', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?


# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['bedrooms'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Quartos de Dormir', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Quais são as características mais comuns das propriedades listadas no Airbnb em diferentes cidades?

# Contar as ocorrências de cada característica para cada cidade
caracteristicas_por_cidade = pd.crosstab(df_final['city'], df_final['beds'])

# Plotar o gráfico de barras empilhadas
caracteristicas_por_cidade.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Características mais comuns das propriedades listadas no Airbnb por cidade')
plt.xlabel('Cidade')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Quantidade de Camas', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Qual é a média de preços de hospedagem em diferentes tipos de propriedades
# (apartamentos, casas, quartos compartilhados, etc.) e em diferentes cidades?

# Suponha que df_final seja o DataFrame contendo seus dados

# Calcular a média de preços de hospedagem para cada tipo de propriedade em cada cidade
average_prices = df_final.groupby(['city', 'property_type'])['log_price'].mean().reset_index()

# Pivotar os dados para ter cidades como índice, tipos de propriedade como colunas e médias de preços como valores
pivot_table = average_prices.pivot(index='city', columns='property_type', values='log_price')

# Visualizar a matriz de correlação
plt.figure(figsize=(18, 12))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Média de Preços de Hospedagem por Tipo de Propriedade e Cidade')
plt.xlabel('Tipo de Propriedade')
plt.ylabel('Cidade')
plt.xticks()
plt.tight_layout()
plt.show()

# %%
# Existe alguma correlação entre o número de comodidades oferecidas e o preço da hospedagem?


# Calcular a correlação entre o número de comodidades e o preço da hospedagem
correlacao = df_final[['log_price', 'accommodates']].corr(method="spearman")

# Visualizar os resultados
plt.figure(figsize=(7,7))
sns.heatmap(correlacao, annot=True, cmap="YlGnBu")
plt.title("Mapa de Correlação", fontsize=15)
plt.show()

# %%
#  Qual é a média de avaliação dos hóspedes em relação à taxa de limpeza cobrada?

average_review_scores = df_final.groupby('cleaning_fee')['review_scores_rating'].mean().reset_index()

# Visualizar os resultados
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=average_review_scores, x='cleaning_fee', y='review_scores_rating', palette='Blues_d')
plt.title('Média de Avaliação dos Hóspedes em Relação à Taxa de Limpeza Cobrada')
plt.xlabel('Faixa de Taxa de Limpeza')
plt.ylabel('Média de Avaliação dos Hóspedes')
plt.xticks(rotation=45)
plt.tight_layout()

for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, (p.get_height())), ha = 'center', color = 'black', size = 11)
    
plt.show()

# %%
df_final.groupby('cleaning_fee')['review_scores_rating'].mean()
# Out:
# cleaning_fee
# False    96.764715
# True     95.600509
# Name: review_scores_rating, dtype: float64

# %%
# Quais são as áreas mais populares (baseadas no número de reservas) em cada cidade?


# Agrupar os dados por cidade e bairro e contar o número total de reservas
popular_areas = df_final.groupby(['city', 'neighbourhood']).size().reset_index(name='total_reservations')

# Encontrar os bairros mais populares em cada cidade
popular_areas = popular_areas.loc[popular_areas.groupby('city')['total_reservations'].idxmax()]

# Ordenar os dados por número total de reservas em ordem decrescente
popular_areas = popular_areas.sort_values(by='total_reservations', ascending=False)

# Visualizar os resultados
plt.figure(figsize=(12, 8))
sns.barplot(data=popular_areas, x='total_reservations', y='neighbourhood', hue='city', dodge=False)
plt.title('Áreas Mais Populares em Cada Cidade (Baseado no Número de Reservas)')
plt.xlabel('Número Total de Reservas')
plt.ylabel('Bairro')
plt.legend(title='Cidade', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
#Qual é a tendência de crescimento do número de propriedades e reservas ao longo dos anos em diferentes cidades?


# Agrupar os dados por cidade e bairro e calcular a média dos preços de hospedagem para cada bairro em cada cidade
average_prices = df_final.groupby(['city', 'neighbourhood'])['log_price'].mean().reset_index()

# Identificar os bairros mais caros e mais baratos em cada cidade
expensive_neighbourhoods = average_prices.loc[average_prices.groupby('city')['log_price'].idxmax()]
cheap_neighbourhoods = average_prices.loc[average_prices.groupby('city')['log_price'].idxmin()]

# Visualizar os resultados
plt.figure(figsize=(12, 8))

# Bairros mais caros
plt.subplot(2, 1, 1)
sns.barplot(data=expensive_neighbourhoods, x='neighbourhood', y='log_price', hue='city', dodge=False)
plt.title('Bairros Mais Caros em Cada Cidade')
plt.xlabel('Bairro')
plt.ylabel('Preço Médio de Hospedagem (log)')
plt.xticks(rotation=45)
plt.legend(title='Cidade',bbox_to_anchor=(1.05, 1), loc='upper left')  # Posiciona a legenda no canto superior direito

# Bairros mais baratos
plt.subplot(2, 1, 2)
sns.barplot(data=cheap_neighbourhoods, x='neighbourhood', y='log_price', hue='city', dodge=False)
plt.title('Bairros Mais Baratos em Cada Cidade')
plt.xlabel('Bairro')
plt.ylabel('Preço Médio de Hospedagem (log)')
plt.xticks(rotation=45)
plt.legend(title='Cidade',bbox_to_anchor=(1.05, 1), loc='upper left')  # Posiciona a legenda no canto superior direito

plt.tight_layout()
plt.show()

# %%
# Salva em CSV
resultado.to_csv('Airbnb_Data_UPDATE.csv', index = False)

# %% [markdown]
# ![Airbnb](imagem/Airbnb.png)
#
# ## Conclusão
#
# Após uma análise abrangente dos dados do Airbnb, podemos destacar algumas características comuns das propriedades listadas em diferentes cidades. Em geral, os tipos de propriedade mais comuns são: Apartamentos, House e bed and breakfasts
# Quanto aos tipos de quarto, observamos uma predominância de listagens para Casa/apartamento inteiro  e quartos privados.
# A maioria das propriedades oferece camas do tipo "Real bed", e a quantidade de quartos e cama em grande maioria é entre 1 e 2.
#
# Quanto à correlação entre o número de comodidades oferecidas e o preço da hospedagem, descobrimos que essa relação é forte, com uma correlação média de 0.59. Isso sugere que o número de comodidades tem um impacto significativo nos preços das hospedagens.
#
# Ao analisar a média de avaliação dos hóspedes em relação à taxa de limpeza cobrada, observamos uma diferença quase insignificante. Para valores de limpeza não cobrada, a média de avaliação foi de 96.76%, enquanto para Cobrados foi de 95.60%.
#
# Em relação às áreas mais populares em cada cidade, encontramos alguns bairros destacados. Por exemplo, em Boston, a área mais popular foi Allston-Brighton, enquanto em São Francisco foi o Mission District, em Nova York, Williamsburg e Chicago, DC e LA ficaram os mais bairros mais populares ficaram como desconhecido.
#
# Por fim, ao examinar as tendências de crescimento do número de propriedades e reservas ao longo dos anos em diferentes cidades, pudemos identificar áreas tanto em crescimento quanto em declínio. Cada cidade apresenta suas próprias tendências distintas de mercado imobiliário, com áreas mais caras e mais baratas para se hospedar.
# No geral ficou da seguinte maneira:
# Cidades mais caras de Boston: Cambridge, Chicago: Magnificent Mile, DC: Chevy Chase MD, LA: Wilmington, NYC: Mill Basin e SF: Sea Cliff.
# Cidades mais baratas de Boston: Somerville, Chicago: South Chicago, DC: Suitland-Silver Hill MD, LA: La Puente, NYC: Morris Park e SF: Daly City."
#
#
# ## Ações
#
# - Com base nas áreas mais populares em cada cidade, os anfitriões localizados nessa área podem considerar estratégias de investimento em marketing para atrair pessoas interessadas em viajar, principalmente a geração millennials, podendo até mesmo promover descontos em datas estratégicas.
#
# - Os anfitriões devem certificar-se de que o perfil e a listagem da propriedade estejam completos e bem otimizados. Isso inclui fotos de alta qualidade, descrições detalhadas e informações precisas sobre comodidades, regras da casa e políticas de cancelamento.
#
# - Otimizar a precificação das hospedagens. Isso pode incluir a implementação de modelos de precificação dinâmica, levando em consideração fatores como sazonalidade, demanda do mercado, características da propriedade e concorrência.
